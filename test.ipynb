# %%
import openai
client = openai.OpenAI(
    base_url= "https://hoa1h32l1xzgof-8000.proxy.runpod.net/v1",
    api_key="3741a669-8c41-4e90-9e27-53d718b4d2e0",
)

# %%
client.models.list()
# Out:
# SyncPage[Model](data=[Model(id='Sao10K/L3.3-70B-Euryale-v2.3', created=1741046318, object='model', owned_by='vllm', root='Sao10K/L3.3-70B-Euryale-v2.3', parent=None, max_model_len=8128, permission=[{'id': 'modelperm-e969e3fd11864d78bfa3665063a64154', 'object': 'model_permission', 'created': 1741046318, 'allow_create_engine': False, 'allow_sampling': True, 'allow_logprobs': True, 'allow_search_indices': False, 'allow_view': True, 'allow_fine_tuning': False, 'organization': '*', 'group': None, 'is_blocking': False}])], object='list')
